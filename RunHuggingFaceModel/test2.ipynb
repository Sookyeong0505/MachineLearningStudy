# %% [markdown]
# # 구글 코랩에 연결해서 진행

# %%
import sys, torch
print(sys.executable)
assert torch.cuda.is_available(), "GPU 미사용!"
print(torch.cuda.get_device_name(0))
# Out:
# C:\projects\PycharmProjects\PythonProject\RunModel\.venv\Scripts\python.exe
# NVIDIA GeForce RTX 2060

# %%
from datasets import load_dataset
from dotenv import load_dotenv
import os


load_dotenv()
dataset = load_dataset("Cheukting/math-meta-reasoning-cleaned", token=os.getenv("HUGGINGFACEHUB_API_TOKEN"))
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'text', 'token_count'],
#         num_rows: 987485
#     })
# })

# %%
from transformers import GPT2Tokenizer


tokenizer = GPT2Tokenizer.from_pretrained("openai-community/gpt2")
tokenizer.pad_token = tokenizer.eos_token


def tokenize_function(examples):
   return tokenizer(examples['text'], truncation=True, padding='max_length', max_length=512)


tokenized_datasets = dataset.map(tokenize_function, batched=True)

# %%
tokenized_datasets_split = tokenized_datasets["train"].shard(num_shards=100, index=0).train_test_split(test_size=0.2, shuffle=True)
tokenized_datasets_split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'text', 'token_count', 'input_ids', 'attention_mask'],
#         num_rows: 7900
#     })
#     test: Dataset({
#         features: ['id', 'text', 'token_count', 'input_ids', 'attention_mask'],
#         num_rows: 1975
#     })
# })

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir='./results4',
    num_train_epochs=3,                  # 3 → 1 (학습용이면 충분)
    per_device_train_batch_size=4,       # 4 → 8 (GPU 활용률↑) <- 8로 늘리면 OOM 발생
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=2,       # 유효 배치는 16으로 유지
    warmup_steps=100,
    weight_decay=0.01,
    save_steps=300,
    save_total_limit=2,                  # ← 디스크 보호, 아래 설명
    logging_steps=100,
    fp16=True,                           # ← 가장 큰 효과
    # dataloader_pin_memory=False,       # ← CUDA에선 삭제 (기본값 True가 맞음)
)

# %%
from transformers import GPT2LMHeadModel, Trainer, DataCollatorForLanguageModeling

model = GPT2LMHeadModel.from_pretrained("openai-community/gpt2")
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)


trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=tokenized_datasets_split['train'],
   eval_dataset=tokenized_datasets_split['test'],
   data_collator=data_collator,
)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]

# %%
trainer.train(resume_from_checkpoint=False)
# Out:
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='2964' max='2964' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2964/2964 22:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>2.107878</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.650985</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.557869</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.490143</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.444119</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.400686</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.374846</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.359807</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.346933</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.304118</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>1.288713</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.256327</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>1.246439</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>1.245918</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.243613</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>1.236772</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>1.235023</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>1.199230</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>1.207351</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.224894</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>1.201053</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>1.182032</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>1.180916</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>1.178520</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.160559</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>1.164340</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>1.149089</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>1.147792</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>1.158435</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=2964, training_loss=1.3055461518034117, metrics={'train_runtime': 1363.7634, 'train_samples_per_second': 17.378, 'train_steps_per_second': 2.173, 'total_flos': 6192621158400000.0, 'train_loss': 1.3055461518034117, 'epoch': 3.0})

# %%
trainer.evaluate(tokenized_datasets_split['test'])
# Out:
#     <div>
#
#       <progress value='247' max='247' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [247/247 00:35]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Step</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1.158435</td>
#       <td>1.139408</td>
#       <td>2964</td>
#     </tr>
#   </tbody>
# </table><p>
# {'eval_loss': 1.139407992362976}

# %%
trainer.save_model("./trained_model4")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
model.push_to_hub("gpt2-math-reasoning", private=True)
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Hyosong/gpt2-math-reasoning/commit/acde0c10d09b9a08ddb1a00f02315320a9d24d0c', commit_message='Upload model', commit_description='', oid='acde0c10d09b9a08ddb1a00f02315320a9d24d0c', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Hyosong/gpt2-math-reasoning', endpoint='https://huggingface.co', repo_type='model', repo_id='Hyosong/gpt2-math-reasoning'), pr_revision=None, pr_num=None)

# %%
# tokenizer.push_to_hub("gpt2-math-reasoning", private=True)
